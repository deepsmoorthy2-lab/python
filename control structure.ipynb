# %%
age=int(input("Enter the age:"))
if(age==18):
    print("adult")
# Out:
# Enter the age: 18
# adult

# %%
age=int(input("enter the age:"))
if(age<18):
    print("Children")
else:
    print("Adult")
# Out:
# enter the age: 17
# Children

# %%
age=int(input("Enter the age:"))
if(age<18):
    print("Children")
elif(age<35):
    print("Adult")
elif(age<59):
    print("Citizen")
else:
    print("Senior Citizen")
# Out:
# Enter the age: 65
# Senior Citizen

# %%
lists=[23,45,68,34,90]
for temp in lists:
    print(temp)
# Out:
# 23
# 45
# 68
# 34
# 90

# %%
lists=[23,45,68,34,90]
for age in lists:
    if(age<18):
        print("Children")
    elif(age<35):
        print("Adult")
    elif(age<59):
        print("Citizen")
    else:
        print("Senior Citizen")
# Out:
# Adult
# Citizen
# Senior Citizen
# Adult
# Senior Citizen
